# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import the dataset
dataset = pd.read_csv('../Data/mapped-table (1).csv')
dataset.head()
# Out:
#    No of people  Household Consumption [kWh/year]  EV distance [KM/year]  \
# 0             2                              2000                      0
# 1             2                              2000                      0
# 2             2                              2000                      0
# 3             2                              2000                      0
# 4             2                              2000                      0
#
#    PV [kWp]  Battery [kWh]  Have heatpump? [y = 1 n = 0]  \
# 0         5              4                             0
# 1         5              4                             0
# 2         5              4                             0
# 3         5              4                             0
# 4         5              4                             1
#
#    Have Heating Rod? [y = 1 n = 0]  Heatpump Consumption [kWh/year]  \
# 0                                0                                0
# ...
